# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandooliveira123/faculdadeAdsUnama/blob/main/Atividade_lads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv"

# %%
df = pd.read_csv(url, sep=';')

# %%
df.shape
# Out:
# (32960, 9)

# %%
df.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
tipo_imoveis = df["Tipo"]

# %%
#agrupar por tipo
df.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
#Qual a media dos mais imoveis barato para os mais caros?
#ordenar os valores sort_values
df.groupby("Tipo")[['Valor']].mean().sort_values('Valor').round()
# Out:
#                                 Valor
# Tipo
# Quitinete                      1247.0
# Pousada/Chalé                  1480.0
# Casa de Vila                   1574.0
# Box/Garagem                    1900.0
# Studio                         2400.0
# Loft                           2558.0
# Flat                           4546.0
# Apartamento                    4745.0
# Chácara                        4900.0
# Casa                           6793.0
# Loja Shopping/ Ct Comercial    8126.0
# Casa de Condomínio            11952.0
# Sítio                         12499.0
# Loja/Salão                    13770.0
# Casa Comercial                14478.0
# Conjunto Comercial/Sala       14715.0
# Loteamento/Condomínio         22000.0
# Hotel                         25000.0
# Terreno Padrão                32568.0
# Galpão/Depósito/Armazém       53407.0
# Indústria                    120000.0
# Prédio Inteiro               498637.0

# %%
import matplotlib.pyplot as plt

# %%
media_imoveis_barato_ao_caro.plot(kind='barh', figsize=(14, 10), color='pink')

# figsize == tamanho da figura = figure size
# kind = tipo
# plotar == imprimir gráfico
# Out:
# <Axes: ylabel='Tipo'>

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Indústria', 'Chácara','Prédio Inteiro', 'Loja/Salão',
                      'Conjunto Comercial/Sala', 'Galpão/Depósito/Armazém',
                      'Box/Garagem', 'Hotel','Sítio', "Pousada/Chalé", "Loteamento/Condomínio"
                      'Casa Comercial']

# %%
# query == consulta

df.query('@imoveis_comerciais in Tipo')
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
df.query('@imoveis_comerciais not in Tipo')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
df_imoveis_menor_ao_maior_2 = df_atualizado.groupby('Tipo')[["Valor"]].mean().sort_values("Valor").round(decimals=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-89-3067017358.py in <cell line: 0>()
# ----> 1 df_imoveis_menor_ao_maior_2 = df_atualizado.groupby('Tipo')[["Valor"]].mean().sort_values("Valor").round(decimals=2)
#
# NameError: name 'df_atualizado' is not defined

# %%
df_imoveis_menor_ao_maior_2.plot(kind='barh', figsize=(14,10), color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-87-33310686.py in <cell line: 0>()
# ----> 1 df_imoveis_menor_ao_maior_2.plot(kind='barh', figsize=(14,10), color="red")
#
# NameError: name 'df_imoveis_menor_ao_maior_2' is not defined

# %%
# Qual a média dos imóveis do mais barato ao mais caro?
# ordena os valores
# sort == ordenar
# sort values --> sort_values()

media_imoveis_barato_ao_caro = df.groupby("Tipo")[['Valor']].mean().sort_values('Valor').round(decimals=2)

# %%
df.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
